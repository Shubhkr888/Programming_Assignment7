# %%
#Question1
array = [1,2,3,4,5,6,7]
sum = 0
for i in array:
  sum = sum+i
print(sum)
# Out:
# 28

# %%
#Question2

list= [110,10,32,7,1000,4]
list.sort(reverse=False)
print(list[-1])
# Out:
# 1000

# %%
#Question3

array1 = [110,10,32,7,1000,4]
print(array1[::-1])
# Out:
# [4, 1000, 7, 32, 10, 110]

# %%
#Question 4
array2 = [110,10,32,7,1000,4]
length= len(array2)
position = int(input())

x=array2[:position]
y=array2[position:]

#print(x,y)
for i in x:
  y.append(i)
print(y)
# Out:
# 2
# [32, 7, 1000, 4, 110, 10]

# %%
#Question 5
array3 = [110,10,32,7,1000,4]
x = array3.sort(reverse=False)
y = array3.sort(reverse=True)
if ((x==array3) or (y==array3)):
  print("Array is monotonic")
else :
    print("Array is non-monotonic")
# Out:
# Array is non-monotonic
